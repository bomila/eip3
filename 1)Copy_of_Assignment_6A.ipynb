
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.15))
model.add(Convolution2D(64, (3, 1), border_mode='same'))
model.add(Convolution2D(64, (1, 3), border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.1))
model.add(Convolution2D(128, (3, 1)))
model.add(Convolution2D(128, (1, 3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.15))
model.add(Convolution2D(128, (3, 1), border_mode='same'))
model.add(Convolution2D(128, (1, 3), border_mode='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Convolution2D(256, 3, 3))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Convolution2D(10, 3, 3, activation='relu'))      
#model.add(Convolution2D(10, (1, 3), activation='relu'))  
model.add(MaxPooling2D(pool_size=(2, 2)))
# add flatten layer
model.add(Flatten())

# add softmax activation function 
model.add(Activation('softmax'))


model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(32, (3, 3), input_shape=(32, 32, 3..., padding="same")`
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:5: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 3))`
#   """
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (3, 1), padding="same")`
#   # Remove the CWD from sys.path while we load stuff.
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:11: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(64, (1, 3), padding="same")`
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:21: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (3, 1), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:22: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(128, (1, 3), padding="same")`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:26: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(256, (3, 3))`
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:29: UserWarning: Update your `Conv2D` call to the Keras 2 API: `Conv2D(10, (3, 3), activation="relu")`

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_11 (Conv2D)           (None, 32, 32, 32)        896
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# activation_8 (Activation)    (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 30, 30, 64)        18496
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 30, 30, 64)        256
# _________________________________________________________________
# activation_9 (Activation)    (None, 30, 30, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 15, 15, 64)        12352
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 15, 15, 64)        12352
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 15, 15, 64)        256
# _________________________________________________________________
# activation_10 (Activation)   (None, 15, 15, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 15, 15, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 13, 15, 128)       24704
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 13, 13, 128)       49280
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 13, 13, 128)       512
# _________________________________________________________________
# activation_11 (Activation)   (None, 13, 13, 128)       0
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 6, 6, 128)         49280
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 6, 6, 128)         49280
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 6, 6, 128)         512
# _________________________________________________________________
# activation_12 (Activation)   (None, 6, 6, 128)         0
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 4, 4, 256)         295168
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 4, 4, 256)         1024
# _________________________________________________________________
# activation_13 (Activation)   (None, 4, 4, 256)         0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 2, 2, 10)          23050
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 1, 1, 10)          0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 10)                0
# _________________________________________________________________
# activation_14 (Activation)   (None, 10)                0
# =================================================================
# Total params: 537,546
# Trainable params: 536,202
# Non-trainable params: 1,344
# _________________________________________________________________

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)



# train the model
start = time.time()
# Train the model
model_info = model.fit_generator(datagen.flow(train_features, train_labels, batch_size = 128),
                                 samples_per_epoch = train_features.shape[0], nb_epoch = 100, 
                                 validation_data = (test_features, test_labels), verbose=1)
end = time.time()
print ("Model took %0.2f seconds to train"%(end - start))
# plot model history
plot_model_history(model_info)
# compute test accuracy
print ("Accuracy on test data is: %0.2f"%accuracy(test_features, test_labels, model))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: The semantics of the Keras 2 argument `steps_per_epoch` is not the same as the Keras 1 argument `samples_per_epoch`. `steps_per_epoch` is the number of batches to draw from the generator at each epoch. Basically steps_per_epoch = samples_per_epoch/batch_size. Similarly `nb_val_samples`->`validation_steps` and `val_samples`->`steps` arguments have changed. Update your method calls accordingly.
#   del sys.path[0]
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:13: UserWarning: Update your `fit_generator` call to the Keras 2 API: `fit_generator(<keras_pre..., validation_data=(array([[[..., verbose=1, steps_per_epoch=390, epochs=100)`
#   del sys.path[0]
# W0630 20:45:07.157687 140218786948992 deprecation.py:323] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Epoch 1/100
# 390/390 [==============================] - 16s 40ms/step - loss: 1.5841 - acc: 0.4524 - val_loss: 1.5366 - val_acc: 0.4950
# Epoch 2/100
# 390/390 [==============================] - 12s 32ms/step - loss: 1.1642 - acc: 0.6008 - val_loss: 1.1778 - val_acc: 0.6036
# Epoch 3/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.9990 - acc: 0.6552 - val_loss: 1.0951 - val_acc: 0.6312
# Epoch 4/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.9020 - acc: 0.6883 - val_loss: 1.0080 - val_acc: 0.6508
# Epoch 5/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.8427 - acc: 0.7080 - val_loss: 0.9346 - val_acc: 0.6770
# Epoch 6/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.7842 - acc: 0.7259 - val_loss: 0.9752 - val_acc: 0.6715
# Epoch 7/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.7403 - acc: 0.7399 - val_loss: 0.9979 - val_acc: 0.6695
# Epoch 8/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.7115 - acc: 0.7495 - val_loss: 0.8172 - val_acc: 0.7134
# Epoch 9/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.6753 - acc: 0.7608 - val_loss: 0.8038 - val_acc: 0.7289
# Epoch 10/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.6531 - acc: 0.7677 - val_loss: 0.8104 - val_acc: 0.7215
# Epoch 11/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.6240 - acc: 0.7785 - val_loss: 0.7886 - val_acc: 0.7281
# Epoch 12/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.6056 - acc: 0.7834 - val_loss: 0.9867 - val_acc: 0.6832
# Epoch 13/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.5815 - acc: 0.7916 - val_loss: 0.8000 - val_acc: 0.7278
# Epoch 14/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.5660 - acc: 0.7949 - val_loss: 0.7814 - val_acc: 0.7366
# Epoch 15/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.5511 - acc: 0.8009 - val_loss: 0.8065 - val_acc: 0.7281
# Epoch 16/100
# 390/390 [==============================] - 12s 30ms/step - loss: 0.
100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2992 - acc: 0.8797 - val_loss: 0.7748 - val_acc: 0.7740
# Epoch 79/100
# 390/390 [==============================] - 12s 32ms/step - loss: 0.2879 - acc: 0.8833 - val_loss: 0.8043 - val_acc: 0.7715
# Epoch 80/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2991 - acc: 0.8790 - val_loss: 0.7752 - val_acc: 0.7750
# Epoch 81/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2915 - acc: 0.8825 - val_loss: 0.7840 - val_acc: 0.7704
# Epoch 82/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2981 - acc: 0.8800 - val_loss: 0.7719 - val_acc: 0.7794
# Epoch 83/100
# 390/390 [==============================] - 12s 32ms/step - loss: 0.2955 - acc: 0.8810 - val_loss: 0.7679 - val_acc: 0.7769
# Epoch 84/100
# 390/390 [==============================] - 12s 32ms/step - loss: 0.2926 - acc: 0.8811 - val_loss: 0.8053 - val_acc: 0.7721
# Epoch 85/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2963 - acc: 0.8803 - val_loss: 0.8733 - val_acc: 0.7660
# Epoch 86/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2913 - acc: 0.8815 - val_loss: 0.9363 - val_acc: 0.7420
# Epoch 87/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2907 - acc: 0.8829 - val_loss: 0.7899 - val_acc: 0.7755
# Epoch 88/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2893 - acc: 0.8833 - val_loss: 0.8723 - val_acc: 0.7687
# Epoch 89/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2934 - acc: 0.8813 - val_loss: 0.8608 - val_acc: 0.7698
# Epoch 90/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2882 - acc: 0.8825 - val_loss: 0.8006 - val_acc: 0.7728
# Epoch 91/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2899 - acc: 0.8830 - val_loss: 0.7829 - val_acc: 0.7737
# Epoch 92/100
# 390/390 [==============================] - 12s 32ms/step - loss: 0.2859 - acc: 0.8844 - val_loss: 0.8638 - val_acc: 0.7666
# Epoch 93/100
# 390/390 [==============================] - 12s 32ms/step - loss: 0.2897 - acc: 0.8820 - val_loss: 0.8300 - val_acc: 0.7696
# Epoch 94/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2852 - acc: 0.8843 - val_loss: 0.8531 - val_acc: 0.7707
# Epoch 95/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2870 - acc: 0.8832 - val_loss: 0.8347 - val_acc: 0.7707
# Epoch 96/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2875 - acc: 0.8830 - val_loss: 0.7968 - val_acc: 0.7752
# Epoch 97/100
# 390/390 [==============================] - 12s 32ms/step - loss: 0.2836 - acc: 0.8848 - val_loss: 0.8410 - val_acc: 0.7649
# Epoch 98/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2827 - acc: 0.8848 - val_loss: 0.7770 - val_acc: 0.7758
# Epoch 99/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2865 - acc: 0.8826 - val_loss: 0.9422 - val_acc: 0.7616
# Epoch 100/100
# 390/390 [==============================] - 12s 31ms/step - loss: 0.2871 - acc: 0.8834 - val_loss: 0.9415 - val_acc: 0.7535
# Model took 1213.39 seconds to train
# Accuracy on test data is: 75.35

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
# !ls /content/gdrive/"My Drive"
# Out:
#  20180816_235621.mp4
#  assests
# 'bhawna cv.gdoc'
# 'Colab Notebooks'
#  frog.jpeg
#  LetsKaggle.ipynb
# 'MINOR PROJECT.gdoc'
#  optistructoptimization10-0-110302221248-phpapp01.pdf
#  paper.doc
# 'PRIYA AGRAWAL             E (1).docx.gdoc'
# 'PRIYA AGRAWAL             E (2).docx.gdoc'
# 'PRIYA AGRAWAL             E (3).docx.gdoc'
# 'PRIYA AGRAWAL             E.docx.gdoc'
# 'resume (2) (1).doc.gdoc'
# 'resume (2) (2).doc.gdoc'
# 'resume (2) (3).doc.gdoc'
# 'resume (2) (4).doc.gdoc'
# 'resume (2) (5).doc.gdoc'
# 'resume (2) (6).doc.gdoc'
# 'resume (2).doc.gdoc'
#  slideshowmovie.mp4

# %% [markdown]
# #Accessing test images
#
# num_classes_test = len(np.unique(test_labels))
#
# class_names = ['airplane','automobile','bird','cat','deer',
#                'dog','frog','horse','ship','truck']
# fig = plt.figure(figsize=(8,3))
# for i in range(num_classes_test):
#     ax = fig.add_subplot(2, 5, 1 + i, xticks=[], yticks=[])
#     idx = np.where(test_labels[:]==i)[0]
#     features_idx = test_features[idx,::]
#     img_num = np.random.randint(features_idx.shape[0])
#     im = features_idx[img_num]
#     ax.set_title(class_names[i])
#     plt.imshow(im)
# plt.show()

# %%
import cv2
from keras.preprocessing import image
import keras.backend as k
import numpy as np
import sys

# %%
datagen = ImageDataGenerator(zoom_range=0.0, 
                             horizontal_flip=False)

x=image.img_to_array(test_features[100])
x=np.expand_dims(x,axis=0)
x=datagen.standardize(x)

preds=model.predict(x)
class_idx=np.argmax(preds[0])
class_output=model.output[:,class_idx]
last_conv_layer=model.get_layer("conv2d_20")

# %%
grads=k.gradients(class_output,last_conv_layer.output)[0]
pooled_grads=k.mean(grads,axis=(0,1,2))
iterate=k.function([model.input],[pooled_grads,last_conv_layer.output[0]])
pooled_grads_value,conv_layer_output_value=iterate([x])

# %%
for i in range(10):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

# %%
heatmap=np.mean(conv_layer_output_value,axis=-1)
heatmap=np.maximum(heatmap,0)
heatmap/=np.max(heatmap)

# %%
heatmap.shape
# Out:
# (32, 32, 3)

# %%
from PIL import Image
img=Image.fromarray(test_features[100],"RGB")
img.save("img1.jpg")

# %%
from google.colab.patches import cv2_imshow
img=cv2.imread("img1.jpg")
heatmap=cv2.resize(heatmap,(32,32))
heatmap=np.uint8(255*heatmap)
heatmap=cv2.applyColorMap(heatmap,cv2.COLORMAP_JET)
superimposed_img=cv2.addWeighted(img,0.0,heatmap,0.4,0)
#cv2_imshow( img)
#cv2_imshow(superimposed_img)
#cv2.waitKey(0)
plt.imshow(img)

# %%
x=image.img_to_array(test_features[80])
x=np.expand_dims(x,axis=0)
x=datagen.standardize(x)



preds = model.predict(x)
class_idx = np.argmax(preds[0])
class_output = model.output[:, class_idx]
last_conv_layer = model.get_layer("conv2d_52")

# %%
grads=k.gradients(class_output,last_conv_layer.output)[0]
pooled_grads=k.mean(grads,axis=(0,1,2))
iterate=k.function([model.input],[pooled_grads,last_conv_layer.output[0]])
pooled_grads_value,conv_layer_output_value=iterate([x])


grads = K.gradients(class_output, last_conv_layer.output)[0]
pooled_grads = K.mean(grads, axis=(0, 1, 2))
iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
pooled_grads_value, conv_layer_output_value = iterate([x])
for i in range(10):
    conv_layer_output_value[:, :, i] *= pooled_grads_value[i]

# %%
heatmap = np.mean(conv_layer_output_value, axis=-1)
heatmap = np.maximum(heatmap, 0)
heatmap /= np.max(heatmap)

# %%
from PIL import Image
img=Image.fromarray(test_features[80],"RGB")
img.save("img1.jpg")

# %%
img = cv2.imread("img1.jpg")
heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
heatmap = np.uint8(255 * heatmap)
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
superimposed_img = cv2.addWeighted(img, 0.6, heatmap, 0.4, 0)
plt.imshow(img)
